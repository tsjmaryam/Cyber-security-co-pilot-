# %% [markdown]
# # Sanity Checks
#
# Load the processed event and incident tables, inspect row counts, null rates, and a few high-value slices.

# %%
from pathlib import Path
import pandas as pd

project_root = Path('..').resolve()
events = pd.read_parquet(project_root / 'data' / 'processed' / 'events_flat')
incidents = pd.read_parquet(project_root / 'data' / 'processed' / 'incidents')
events[['event_time', 'actor_key', 'event_name', 'source_ip_address']].head()
